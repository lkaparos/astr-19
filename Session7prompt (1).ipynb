# %%
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
x=np.linspace(0,1,100)

# %% [markdown]
# defines function that will return exp(x)

# %%
def exponential_function(x):
    return np.exp(x)

# %% [markdown]
# set y=exp(x)

# %%
y=np.exp(x)

# %%
plt.plot(x,y, label="y=exp(x)")
plt.xlabel("time[milliseconds]")
plt.ylabel("awesomeness")
# Out:
# Text(0, 0.5, 'awesomeness')

# %%
pdf_file_name="sesssion7prompt.pdf"
plt.savefig(pdf_file_name,format="pdf")
